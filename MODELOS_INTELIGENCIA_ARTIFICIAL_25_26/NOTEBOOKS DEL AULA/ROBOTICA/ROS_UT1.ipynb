# %% [markdown]
# # Desarrollo de aplicaciones con el brazo robótico Yahboom DOFBOT (Jetson Nano)
#
#
# ## 0. Guía general del curso
# - Objetivo global
# - Aprender, paso a paso, a:
#     - Encender y configurar el brazo robótico DOFBOT con Jetson Nano.
#     - Controlar sus servomotores desde programas sencillos en Python.
#     - Usar la cámara y realizar tareas básicas de visión artificial.
#     - Integrar visión y movimiento para crear pequeñas aplicaciones interactivas.
#
# ## Unidad 1. Conociendo el DOFBOT y puesta en marcha
#
# ### 1.1. ¿Qué es el DOFBOT?
#
# DOFBOT es un brazo robótico educativo de 6 grados de libertad (6 DOF).
#
# Incluye:
#
# - Base giratoria.
# - Articulaciones del “hombro”, “codo” y “muñeca”.
# - Pinza (garra) para agarrar objetos.
# - Cámara en el extremo (en algunos modelos).
# - Placa Jetson Nano (mini-ordenador con GPU de NVIDIA).
# - Placa de expansión para conectar servos, sensores y alimentación.
#
# 🔎 Conceptos clave:
#
# - DOF (Degree of Freedom): cada movimiento independiente que puede hacer el robot (girar, subir, bajar, etc.).
# - Servo: motor especial que gira hasta un ángulo concreto.
# - Jetson Nano: pequeño ordenador (como un “mini PC”) preparado para IA y visión artificial.

# %% [markdown]
# 1.2. Encendido y conexiones básicas
#
# Esta parte se hace preferiblemente como demostración inicial del profesor y luego el alumnado repite en parejas.
#
# Pasos básicos:
#
# 1. Colocar el Jetson Nano en su base o estructura del robot.
#
# 2. Conectar:
#
#     - Tarjeta microSD con la imagen del sistema ya preparada (SO + software de Yahboom).
#     - Cable de alimentación del Jetson Nano.
#     - Fuente de alimentación del brazo robótico (según el kit).
#     - Cable de red o WiFi (si es necesario).
#     - Ratón, teclado y pantalla (o acceso remoto por red).
# 3. Encender el sistema y comprobar que aparece el escritorio de Ubuntu (o similar).

# %% [markdown]
# 1.3. Primer contacto con el sistema
#
# 1. Abrir una terminal.
# 2. Comprobar la versión de Python:

# %%
python3 --version

# %% [markdown]
# 3. Crear una carpeta de trabajo, por ejemplo:

# %%
mkdir dofbot_proyectos
cd dofbot_proyectos

# %% [markdown]
# 1.4. Hello World del robot: primer movimiento sencillo
#
# Este primer ejemplo puede venir ya preparado en la imagen de Yahboom o se puede proporcionar un script simple.
#
# **Idea**: mover solo un servo unos grados, por ejemplo el de la base.
#
# Ejemplo simplificado (pseudo-código):

# %%
# mover_servo_base.py
from dofbot_control import ServoController   # Nombre ficticio, adaptarlo a la librería real

# Crear controlador de servos
controlador = ServoController()

# Elegir el servo de la base (por ejemplo ID = 1)
servo_base = 1

# Mover la base a 90 grados
controlador.move_servo(servo_base, 90)

# Esperar un poco para ver el movimiento
import time
time.sleep(2)

# Volver a 0 grados
controlador.move_servo(servo_base, 0)
