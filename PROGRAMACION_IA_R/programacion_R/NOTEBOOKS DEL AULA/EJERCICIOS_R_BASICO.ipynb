# %% [markdown]
# # MANUAL DE EJERCICIOS BÁSICOS EN RStudio (enunciados)
#
#
# ## Introducción
#
# DICCIONARIO DE FUNCIONES EN R
#
# | FUNCIÓN	| APLICACIÓN O USO |
# |-----------|------------------|
# |readline()	| Sirve para poner una línea de texto que se presentará en la consola solicitando algún dato o información al usuario.|
# |as.numeric()|	Lee un texto como numérico.|
# |cat()|	Nos permite imprimir en la consola lineas de texto junto con variables que hayamos ingresado antes.|
# |ordered|	Esta función nos ayuda a colocar en orden datos numéricos usando el signo de menor ( < ).
# |sort	|Ordena de manera directa números sin usar ningun signo. Dentro de este código es necesario indicar si el orden será creciente o decreciente, para ello colocaremos decreasing = y colocar FALSE para una secuencia creciente o TRUE para una decreciente. Ejemplo: r <- sort(numeros,decreasing = FALSE)

# %% [markdown]
# ## Ejercicio 1
#
# Elabore un programa el cual solicite al usuario ingrese los valores de los catetos de un triángulo rectángulo, y a su vez obtenga como resultado el valor de la hipotenusa.

# %%
# Salida esperada:
cat("El valor de los catetos del triángulo rectángulo son: ","\n",
    "Cateto Mayor: ",cat1,"\n",
    "Cateto Menor: ",cat2,"\n",
    "La hipotenusa del triángulo rectángulo es: ",hip)

# %% [markdown]
# ## Ejercicio 2
#
# Un estudiante de bachillerato tiene que encontrar el valor de x una ecuación de segundo grado de la forma ax^2+bx+c=0, por tal motivo, vamos a realizar un programa que nos ayude calcular ese valor de x de manera rápida, aquí los valores de a, b y c los ingresa el usuario, en este caso el estudiante.

# %%
# Escribe aquí tu solución en Python

# %% [markdown]
# ## Ejercicio 3
#
# Se necesita calcular el área de un triángulo, para ello cree un script donde se tenga que ingresar el valor de la base y altura.

# %%
# Escribe aquí tu solución en Python

# %% [markdown]
# ## Ejercicio 4
#
# Calcular el área y perímetro de un rectángulo dada su base y altura.
#
# - La base de del rectángulo es: 18 cm
# - La altura del rectángulo es: 12 cm

# %%
# Escribe aquí tu solución en Python

# %% [markdown]
# ## Ejercicio 5
#
# Para ayudar a un profesor a calcular los promedios de notas sobre 20 de sus estudiantes, se creará un programa. En este mismo el docente será quién introducirá las 3 notas necesarias para el cálculo del promedio.

# %%
# Escribe aquí tu solución en Python

# %% [markdown]
# ## Ejercicio 6
#
# CALCULAR EL ÁREA Y PERÍMETRO DE LA CIRCUNFERENCIA DADO EL RADIO
#
# EL RADIO DE LA CIRCUFERENCIA ES: 10 cm

# %%
# Escribe aquí tu solución en Python

# %% [markdown]
# ## Ejercicio 7
#
# Elaborar un programa que pida al usuario ingresar la base mayor ,la base menor y altura de un trapecio y de cómo resultados su área.
#
# - Área del trapecio = [(base mayor + base menor)/2] * altura

# %%
# Escribe aquí tu solución en Python

# %% [markdown]
# ## Ejercicio 8
#
# Realizar un programa que solicite al usuario dos números, y como resultado entregue cual de estos es el mayor y menor de los dos, dado el caso si los dos números son iguales, informar al usuario mediante un mensaje.

# %%
# Escribe aquí tu solución en Python

# %% [markdown]
# ## Ejercicio 9
#
# Suma de enteros: Calcular la suma de los $n$ primeros números enteros positivos usando la fórmula $\frac{n(n+1)}{2}$.

# %%
# Escribe aquí tu solución en Python

# %% [markdown]
# ## Ejercicio 10
#
# Índice de Masa Corporal (IMC): Solicitar peso (kg) y estatura (m) para calcular el IMC redondeado a dos decimales.

# %%
# Escribe aquí tu solución en Python

# %% [markdown]
# ## Ejercicio 11
#
# Ordenación de números: Solicitar 5 números al usuario y mostrarlos ordenados de forma ascendente.

# %%
# Escribe aquí tu solución en Python

# %% [markdown]
# ## Ejercicio 12
#
# Factorial: Escribir un programa que calcule el factorial de un número digitado por el usuario.

# %%
# Escribe aquí tu solución en Python

# %% [markdown]
# ## Ejercicio 13
#
# Números Primos: Pedir un número e indicar si es primo o no.

# %%
# Escribe aquí tu solución en Python

# %% [markdown]
# ## Ejercicio 14
#
# Par o Impar: Determinar si un número ingresado por el usuario es par o impar.

# %%
# Escribe aquí tu solución en Python

# %% [markdown]
# ## Ejercicio 15
#
# Elaborar un programa para un cliente de un supermercado que le ayude a calcular el valor del IVA (12%) y el valor TOTAL que debe pagar por sus compras, sabiendo ya cuál es el valor total de todos los productos que desea comprar antes de aplicar el IVA.

# %%
# Escribe aquí tu solución en Python
